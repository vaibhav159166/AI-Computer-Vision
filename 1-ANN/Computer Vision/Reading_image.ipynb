# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread("some/wrong/path")

# %%
print(img)
# Out:
# None

# %%
# Correct Path

# %%
img=cv2.imread("C:/2-Computer_Vision/00-puppy.jpg")

# %%
print(img)
# Out:
# [[[78 81 95]
#   [80 83 97]
#   [81 84 98]
#   ...
#   [22 27 25]
#   [22 27 25]
#   [22 27 25]]
#
#  [[78 81 95]
#   [79 82 96]
#   [79 82 96]
#   ...
#   [22 27 25]
#   [22 27 25]
#   [22 27 25]]
#
#  [[78 81 95]
#   [77 80 94]
#   [77 80 94]
#   ...
#   [22 27 25]
#   [22 27 25]
#   [22 27 25]]
#
#  ...
#
#  [[20 29 19]
#   [21 30 20]
#   [21 30 20]
#   ...
#   [22 30 23]
#   [23 31 24]
#   [23 31 24]]
#
#  [[21 30 20]
#   [21 30 20]
#   [20 29 19]
#   ...
#   [22 30 23]
#   [23 31 24]
#   [23 31 24]]
#
#  [[21 30 20]
#   [20 29 19]
#   [20 29 19]
#   ...
#   [22 30 23]
#   [23 31 24]
#   [23 31 24]]]

# %%
img_bar=cv2.imread("C:/2-Computer_Vision/00-puppy.jpg")
plt.imshow(img_bar)

# %% [markdown]
# The image has been correctly located by opencv as a numpy array, But the color of each pixel has been sorted to

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_gray=cv2.imread("C:/2-Computer_Vision/00-puppy.jpg",cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_gray=cv2.imread("C:/2-Computer_Vision/00-puppy.jpg",cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap="gray")

# %% [markdown]
# ### Resize Images

# %%
img_rgb.shape
# height , width, color channels
# Out:
# (1300, 1950, 3)

# %%
img=cv2.resize(img_rgb,(1300,275))

# %%
plt.imshow(img)

# %% [markdown]
# ### By Ratio

# %%
import cv2

w_ratio=0.5
h_ratio=0.5

# Resize the image
new_img=cv2.resize(img_rgb,(0,0),fx=w_ratio,fy=h_ratio)

'''
This is a function from the OpenCV library that resizes an image.
'''

# %%
plt.imshow(new_img)
